# %% [markdown]
# # Downloading Analysits' Recommendations

# %%
from yahoofinancials import YahooFinancials
import yfinance as yf 
import pandas as pd
import numpy as np

# %%
tickerSymbol = 'AAPL'


tickerData = yf.Ticker(tickerSymbol)


Recommendation = tickerData.recommendations

Recommendation
# Out:
#                                   Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00  Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00     FBN Securities    Outperform              main
# 2012-03-13 06:08:00          Jefferies           Buy              main
# 2012-03-14 06:13:00     Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00  Canaccord Genuity           Buy              main
# ...                                ...           ...        ...    ...
# 2023-01-11 11:56:45           Barclays  Equal-Weight              main
# 2023-01-13 14:18:55         Rosenblatt           Buy              main
# 2023-01-18 13:22:02  Canaccord Genuity           Buy              main
# 2023-01-19 11:27:43          JP Morgan    Overweight              main
# 2023-01-23 11:28:05      Deutsche Bank           Buy              main
#
# [879 rows x 4 columns]

# %%
Recommendation.to_excel('APPL_rec.xlsx')
