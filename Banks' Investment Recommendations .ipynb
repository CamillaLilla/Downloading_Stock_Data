# %%
from yahoofinancials import YahooFinancials
import yfinance as yf 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tickerSymbol = 'MSFT'


tickerData = yf.Ticker(tickerSymbol)


Recomendation = tickerData.recommendations 

Recomendation
# Out:
#                                Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00  Argus Research            Buy                up
# 2012-03-19 14:00:00  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00  Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00             UBS            Buy              main
# 2012-04-20 06:18:00   Deutsche Bank            Buy              main
# ...                             ...            ...        ...    ...
# 2022-04-27 11:42:42          Stifel            Buy              main
# 2022-04-27 11:46:09         Wedbush     Outperform              main
# 2022-05-23 13:36:08       Jefferies            Buy              main
# 2022-06-10 11:14:54        Barclays     Overweight              main
# 2022-06-13 13:37:26       Jefferies            Buy              main
#
# [376 rows x 4 columns]

# %%
Recomendation.resample('1q', label='right').last()
# Out:
#                                   Firm        To Grade  From Grade Action
# Date
# 2012-03-31              Morgan Stanley      Overweight               main
# 2012-06-30        McAdams Wright Ragen             Buy               main
# 2012-09-30                   Jefferies            Hold               init
# 2012-12-31  SunTrust Robinson Humphrey         Neutral               init
# 2013-03-31        McAdams Wright Ragen             Buy               main
# 2013-06-30              Morgan Stanley      Overweight               main
# 2013-09-30              Morgan Stanley    Equal-Weight  Overweight   down
# 2013-12-31           Evercore Partners      Overweight               main
# 2014-03-31                 Cowen & Co.  Market Perform               main
# 2014-06-30                   Citigroup         Neutral               main
# 2014-09-30                MKM Partners             Buy               init
# 2014-12-31             Bank of America    Underperform     Neutral   down
# 2015-03-31               Pacific Crest      Outperform               main
# 2015-06-30                   Jefferies    Underperform               main
# 2015-09-30             Stifel Nicolaus             Buy        Hold     up
# 2015-12-31               Goldman Sachs         Neutral        Sell     up
# 2016-03-31                   Macquarie         Neutral               init
# 2016-06-30                 Cowen & Co.      Outperform                 up
# 2016-09-30                         UBS             Buy               main
# 2016-12-31                PiperJaffray      Overweight               init
# 2017-03-31           Tigress Financial             Buy     Neutral     up
# 2017-06-30          Cleveland Research             Buy               init
# 2017-09-30           Moffett Nathanson         Neutral               init
# 2017-12-31                         UBS             Buy               main
# 2018-03-31              Morgan Stanley      Overweight  Overweight   main
# 2018-06-30                       Argus             Buy         Buy   main
# 2018-09-30                    Barclays      Overweight  Overweight   main
# 2018-12-31                   Citigroup         Neutral     Neutral   main
# 2019-03-31                      Mizuho             Buy               init
# 2019-06-30                   Jefferies    Underperform               main
# 2019-09-30                 BMO Capital      Outperform               main
# 2019-12-31                     Wedbush      Outperform               main
# 2020-03-31                   Citigroup         Neutral               main
# 2020-06-30               Goldman Sachs             Buy               main
# 2020-09-30              Morgan Stanley      Overweight               main
# 2020-12-31                   Citigroup             Buy     Neutral     up
# 2021-03-31              Morgan Stanley      Overweight               main
# 2021-06-30                   Jefferies             Buy               main
# 2021-09-30                    Barclays      Overweight               main
# 2021-12-31                  SMBC Nikko      Outperform               init
# 2022-03-31           Tigress Financial             Buy               main
# 2022-06-30                   Jefferies             Buy               main

# %%
Recomendation.to_excel('2. msft_Rec .xlsx')
